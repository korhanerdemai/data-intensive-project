# %% [markdown]
# Dataset: **Sleep-EDF Expanded**
# https://physionet.org/content/sleep-edfx/1.0.0/

# %%
# !pip install mne pyedflib seglearn tsfel tsfresh antropy plotly-resampler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mne
#   Downloading mne-1.6.1-py3-none-any.whl (8.3 MB)
#      ---------------------------------------- 8.3/8.3 MB 8.1 MB/s eta 0:00:00
# Collecting pyedflib
#   Downloading pyEDFlib-0.1.37-cp38-cp38-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 10.8 MB/s eta 0:00:00
# Collecting seglearn
#   Downloading seglearn-1.2.5-py3-none-any.whl (11.3 MB)
#      --------------------------------------- 11.3/11.3 MB 14.9 MB/s eta 0:00:00
# Collecting tsfel
#   Downloading tsfel-0.1.7-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Collecting tsfresh
#   Downloading tsfresh-0.20.2-py2.py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.8/95.8 kB ? eta 0:00:00
# Collecting antropy
#   Downloading antropy-0.1.6.tar.gz (17 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting plotly-resampler
#   Downloading plotly_resampler-0.10.0-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.7/80.7 kB 4.7 MB/s eta 0:00:00
# Collecting pooch>=1.5
#   Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#      ---------------------------------------- 63.0/63.0 kB ? eta 0:00:00
# Collecting importlib-resources>=5.10.2
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (21.3)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (1.8.1)
# Requirement already satisfied: tqdm in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (4.64.0)
# Requirement already satisfied: decorator in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (3.1.2)
# Collecting lazy-loader>=0.3
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (1.22.4)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from mne) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from seglearn) (1.1.1)
# Requirement already satisfied: ipython>=7.4.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from tsfel) (8.7.0)
# Collecting pandas>=1.5.3
#   Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#      --------------------------------------- 10.8/10.8 MB 14.9 MB/s eta 0:00:00
# Collecting setuptools>=47.1.1
#   Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Collecting statsmodels>=0.12.0
#   Downloading statsmodels-0.14.1-cp38-cp38-win_amd64.whl (10.0 MB)
#      --------------------------------------- 10.0/10.0 MB 13.4 MB/s eta 0:00:00
# Collecting stumpy>=1.7.2
#   Downloading stumpy-1.12.0-py3-none-any.whl (169 kB)
#      ------------------------------------- 169.1/169.1 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in c:\users\erdem\appdata\roaming\python\python38\site-packages (from tsfresh) (2.1.0)
# Requirement already satisfied: requests>=2.9.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from tsfresh) (2.31.0)
# Collecting patsy>=0.4.1
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ------------------------------------- 233.9/233.9 kB 14.9 MB/s eta 0:00:00
# Collecting stochastic
#   Downloading stochastic-0.7.0-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.1/48.1 kB ? eta 0:00:00
# Collecting numba>=0.57
#   Downloading numba-0.58.1-cp38-cp38-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 16.8 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.10.1-cp38-none-win_amd64.whl (138 kB)
#      -------------------------------------- 138.8/138.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: plotly<6.0.0,>=5.5.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from plotly-resampler) (5.18.0)
# Collecting tsdownsample>=0.1.3
#   Downloading tsdownsample-0.1.3-cp38-none-win_amd64.whl (923 kB)
#      ------------------------------------- 923.4/923.4 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: dash>=2.9.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from plotly-resampler) (2.14.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (2.0.0)
# Requirement already satisfied: retrying in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (1.3.4)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (5.0.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (3.0.1)
# Requirement already satisfied: ansi2html in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (1.8.0)
# Requirement already satisfied: importlib-metadata in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (4.12.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (4.9.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (3.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (1.5.6)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from dash>=2.9.0->plotly-resampler) (2.0.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from importlib-resources>=5.10.2->mne) (3.8.0)
# Requirement already satisfied: pickleshare in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (0.1.6)
# Requirement already satisfied: backcall in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (5.6.0)
# Requirement already satisfied: stack-data in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (0.6.2)
# Requirement already satisfied: colorama in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (0.4.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from ipython>=7.4.0->tsfel) (3.0.33)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (8.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (4.47.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from matplotlib>=3.5.0->mne) (2.4.7)
# Collecting llvmlite<0.42,>=0.41.0dev0
#   Downloading llvmlite-0.41.1-cp38-cp38-win_amd64.whl (28.1 MB)
#      --------------------------------------- 28.1/28.1 MB 10.9 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ------------------------------------- 345.4/345.4 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from pandas>=1.5.3->tsfel) (2020.5)
# Requirement already satisfied: six in c:\users\erdem\appdata\roaming\python\python38\site-packages (from patsy>=0.4.1->tsfresh) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from plotly<6.0.0,>=5.5.0->plotly-resampler) (8.2.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from pooch>=1.5->mne) (4.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from requests>=2.9.1->tsfresh) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from requests>=2.9.1->tsfresh) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from requests>=2.9.1->tsfresh) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from requests>=2.9.1->tsfresh) (2022.6.15)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.21.3->seglearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.21.3->seglearn) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from jinja2->mne) (2.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler) (1.7.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler) (8.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from jedi>=0.16->ipython>=7.4.0->tsfel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\erdem\appdata\roaming\python\python38\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=7.4.0->tsfel) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from stack-data->ipython>=7.4.0->tsfel) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\erdem\appdata\roaming\python\python38\site-packages (from stack-data->ipython>=7.4.0->tsfel) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\erdem\appdata\roaming\python\python38\site-packages (from stack-data->ipython>=7.4.0->tsfel) (1.2.0)
# Building wheels for collected packages: antropy
#   Building wheel for antropy (pyproject.toml): started
#   Building wheel for antropy (pyproject.toml): finished with status 'done'
#   Created wheel for antropy: filename=antropy-0.1.6-py3-none-any.whl size=16889 sha256=497062d53cc744213dfeff2468905df64b110ed74b37db8d374d63bb92d4d010
#   Stored in directory: c:\users\erdem\appdata\local\pip\cache\wheels\ae\bf\54\c1ea18fc2c20aae8bfe7605bdaed49e1caf8050ed0af449262
# Successfully built antropy
# Installing collected packages: tzdata, tsdownsample, setuptools, pyedflib, patsy, orjson, llvmlite, importlib-resources, stochastic, pooch, pandas, numba, lazy-loader, stumpy, statsmodels, seglearn, mne, antropy, tsfresh, tsfel, plotly-resampler
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.7.7
#     Uninstalling orjson-3.7.7:
#       Successfully uninstalled orjson-3.7.7
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.8.0
#     Uninstalling importlib-resources-5.8.0:
#       Successfully uninstalled importlib-resources-5.8.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.0
#     Uninstalling pandas-1.2.0:
#       Successfully uninstalled pandas-1.2.0
# Successfully installed antropy-0.1.6 importlib-resources-6.4.0 lazy-loader-0.4 llvmlite-0.41.1 mne-1.6.1 numba-0.58.1 orjson-3.10.1 pandas-2.0.3 patsy-0.5.6 plotly-resampler-0.10.0 pooch-1.8.1 pyedflib-0.1.37 seglearn-1.2.5 setuptools-69.5.1 statsmodels-0.14.1 stochastic-0.7.0 stumpy-1.12.0 tsdownsample-0.1.3 tsfel-0.1.7 tsfresh-0.20.2 tzdata-2024.1
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erdem\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\erdem\appdata\roaming\python\python38\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../src/")

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mne
import tsflex

from tqdm.auto import tqdm

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from plotly_resampler import FigureResampler

# %% [markdown]
# ## Download the data

# %% [markdown]
# Commands to download and extract the data;
# ```sh
# mkdir data
# wget https://physionet.org/static/published-projects/sleep-edfx/sleep-edf-database-expanded-1.0.0.zip -P data
# # Extrac all data
# unzip data/sleep-edf-database-expanded-1.0.0.zip -d data
# ```

# %% [markdown]
# # Data loading

# %% [markdown]
# ## Some EDF loading funcs

# %%
from src.data import load_signals, load_annotations, annotation_to_30s_labels

# %% [markdown]
# ## Load some data

# %%
data_folder = "./sleep-edf-database-expanded-1.0.0/"

os.listdir(data_folder)
# Out:
# ['RECORDS',
#  'RECORDS-v1',
#  'SC-subjects.xls',
#  'SHA256SUMS.txt',
#  'sleep-cassette',
#  'sleep-telemetry',
#  'ST-subjects.xls']

# %%
os.listdir(data_folder + "sleep-cassette")[:10]
# Out:
# ['SC4001E0-PSG.edf',
#  'SC4001EC-Hypnogram.edf',
#  'SC4002E0-PSG.edf',
#  'SC4002EC-Hypnogram.edf',
#  'SC4011E0-PSG.edf',
#  'SC4011EH-Hypnogram.edf',
#  'SC4012E0-PSG.edf',
#  'SC4012EC-Hypnogram.edf',
#  'SC4021E0-PSG.edf',
#  'SC4021EH-Hypnogram.edf']

# %%
len(os.listdir(data_folder + "sleep-cassette"))
# Out:
# 306

# %%
# !du -hs ../../../../data/sleep/sleep-edf-database-expanded-1.0.0/sleep-cassette
# Out:
# 'du' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# => In total 306 files (153 PSG files - 153 hypnogram files) => 7.1 GB

# %%
dfs = []
sub_folder = "sleep-cassette"
sorted_files = sorted(os.listdir(data_folder + sub_folder))
psg_hypnogram_files = [(p, h) for p, h in zip(sorted_files[::2], sorted_files[1:][::2])]
df_files = pd.DataFrame(psg_hypnogram_files, columns=["psg_file", "label_file"])
df_files["subfolder"] = sub_folder

# Because for the SC study patients were monitored for 2 consecutive nights
df_files["patient_id"] = df_files.psg_file.apply(lambda f: f[:5])
df_files
# Out:
#              psg_file              label_file       subfolder patient_id
# 0    SC4001E0-PSG.edf  SC4001EC-Hypnogram.edf  sleep-cassette      SC400
# 1    SC4002E0-PSG.edf  SC4002EC-Hypnogram.edf  sleep-cassette      SC400
# 2    SC4011E0-PSG.edf  SC4011EH-Hypnogram.edf  sleep-cassette      SC401
# 3    SC4012E0-PSG.edf  SC4012EC-Hypnogram.edf  sleep-cassette      SC401
# 4    SC4021E0-PSG.edf  SC4021EH-Hypnogram.edf  sleep-cassette      SC402
# ..                ...                     ...             ...        ...
# 148  SC4802G0-PSG.edf  SC4802GV-Hypnogram.edf  sleep-cassette      SC480
# 149  SC4811G0-PSG.edf  SC4811GG-Hypnogram.edf  sleep-cassette      SC481
# 150  SC4812G0-PSG.edf  SC4812GV-Hypnogram.edf  sleep-cassette      SC481
# 151  SC4821G0-PSG.edf  SC4821GC-Hypnogram.edf  sleep-cassette      SC482
# 152  SC4822G0-PSG.edf  SC4822GC-Hypnogram.edf  sleep-cassette      SC482
#
# [153 rows x 4 columns]

# %%
paper_patients = [
    "SC400",
    "SC401",
    "SC402",
    "SC403",
    "SC404",
    "SC405",
    "SC406",
    "SC407",
    "SC408",
    "SC409",
    "SC410",
    "SC411",
    "SC412",
    "SC413",
    "SC414",
    "SC415",
    "SC416",
    "SC417",
    "SC418",
    "SC419",
]

# %%
df_files_paper = df_files[df_files.patient_id.isin(paper_patients)]
df_files_paper.psg_file.nunique()
# Out:
# 39

# %%
df_files_paper.patient_id.nunique()
# Out:
# 20

# %% [markdown]
# => psg file can be used as recordingid
# => patient id can be used as patient id

# %%
df_files_other = df_files[~df_files.patient_id.isin(paper_patients)]
df_files_other.psg_file.nunique()
# Out:
# 114

# %%
df_files_other.patient_id.nunique()
# Out:
# 58

# %%
signal_dict = {}

for idx in range(len(df_files)):
    sig, freq = load_signals(
        data_folder + df_files.iloc[idx].subfolder + "/" + df_files.iloc[idx].psg_file,
        only_info=True,
    )
    for s, f in zip(sig, freq):
        if (s, f) in signal_dict.keys():
            signal_dict[(s, f)].append(idx)
        else:
            signal_dict[(s, f)] = [idx]

# Displays (sig, freq) #recordings
[(k, len(v)) for k, v in signal_dict.items()]
# Out:
# [(('EEG Fpz-Cz', 100.0), 153),
#  (('EEG Pz-Oz', 100.0), 153),
#  (('EOG horizontal', 100.0), 153),
#  (('Resp oro-nasal', 1.0), 153),
#  (('EMG submental', 1.0), 153),
#  (('Temp rectal', 1.0), 153),
#  (('Event marker', 1.0), 153)]

# %%
common_signals = [
    "EEG Fpz-Cz",
    "EEG Pz-Oz",
    "EOG horizontal",  # All have the same sampling rate (100 Hz)
    "EMG submental",  # Different sampling rate: 100 Hz for telemetry & 1 Hz for cassette
]

# %%
data = load_signals(
    data_folder + df_files.iloc[0].subfolder + "/" + df_files.iloc[0].psg_file,
    retrieve_signals=common_signals,
)
annotations = load_annotations(
    data_folder + df_files.iloc[0].subfolder + "/" + df_files.iloc[0].label_file,
    data_folder + df_files.iloc[0].subfolder + "/" + df_files.iloc[0].psg_file,
)

# %%
cats = [
    "Sleep stage ?",
    "Movement time",
    "Sleep stage W",
    "Sleep stage 1",
    "Sleep stage 2",
    "Sleep stage 3",
    "Sleep stage 4",
    "Sleep stage R",
][::-1]

# %% [markdown]
# # EDA + pipeline (for 1 patient)

# %%
idxs = [s.name for s in data]

fig = FigureResampler(
    make_subplots(
        rows=len(idxs) + 1,
        cols=1,
        shared_xaxes=True,
        subplot_titles=idxs + ["Hypnogram"],
        vertical_spacing=0.05,
    ),
    default_n_shown_samples=2_000,
)

for idx, s in enumerate(data, 1):
    fig.add_trace(
        go.Scattergl(
            x=[],
            y=[],
            name=s.name,
            line_width=1,
        ),
        hf_x=s.index,
        hf_y=s.values,
        row=idx,
        col=1,
    )

fig.add_trace(
    go.Scattergl(
        x=[],
        y=[],
        name="Hypnogram",
        line_width=1.5,
        line_shape="hv",
    ),
    hf_x=annotation_to_30s_labels(annotations).index,
    hf_y=annotation_to_30s_labels(annotations)["label"].astype("category"),
    row=len(idxs) + 1,
    col=1,
)

fig.update_layout(height=900)
fig.update_yaxes(categoryorder="array", categoryarray=cats)

fig.update_layout(
    legend_traceorder="normal",
    template="plotly_dark",
    #     legend=dict(orientation="h", y=1.07, xanchor="right", x=1),
)

fig.show_dash(port=8041)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8041/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Process the signals

# %%
## Processing
from scipy.signal import butter, lfilter

from tsflex.processing import SeriesPipeline, SeriesProcessor


def butter_bandpass_filter(sig, lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype="band")
    y = lfilter(b, a, sig)
    return y


# def clipper(sig, min_q=0, max_q=1):
#     return sig.clip(sig.quantile(min_q), sig.quantile(max_q))


eeg_bandpass = SeriesProcessor(
    function=butter_bandpass_filter,
    series_names=["EEG Fpz-Cz", "EEG Pz-Oz", "EOG horizontal"],
    lowcut=0.4,
    highcut=30,
    fs=100,
)

process_pipe = SeriesPipeline(
    [
        eeg_bandpass,
    ]
)

process_pipe
# Out:
# [
# 	butter_bandpass_filter {'lowcut': 0.4, 'highcut': 30, 'fs': 100} :  ('EEG Fpz-Cz',) ('EEG Pz-Oz',) ('EOG horizontal',)
# ]

# %%
# %%time
data_processed = process_pipe.process(data, return_all_series=True)
# Out:
# CPU times: total: 234 ms
# Wall time: 249 ms

# %%
for s in data_processed:
    idx = idxs.index(s.name.split("_")[-1]) + 1
    fig.add_trace(
        go.Scatter(x=[], y=[], name=s.name + " processed", line_width=1),
        hf_x=s.index,
        hf_y=s.values,
        row=idx,
        col=1,
    )

fig.show_dash(port=8041)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8041/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Extract the features

# %%
# Create the collection of tsfresh features to extract

tsfresh_settings = {
    "fft_aggregated": [
        {"aggtype": "centroid"},
        {"aggtype": "variance"},
        {"aggtype": "skew"},
        {"aggtype": "kurtosis"},
    ],
    "fourier_entropy": [
        {"bins": 2},
        {"bins": 3},
        {"bins": 5},
        {"bins": 10},
        {"bins": 30},
        {"bins": 60},
        {"bins": 100},
    ],
    "binned_entropy": [
        {"max_bins": 5},
        {"max_bins": 10},
        {"max_bins": 30},
        {"max_bins": 60},
    ],
}

tsfresh_settings
# Out:
# {'fft_aggregated': [{'aggtype': 'centroid'},
#   {'aggtype': 'variance'},
#   {'aggtype': 'skew'},
#   {'aggtype': 'kurtosis'}],
#  'fourier_entropy': [{'bins': 2},
#   {'bins': 3},
#   {'bins': 5},
#   {'bins': 10},
#   {'bins': 30},
#   {'bins': 60},
#   {'bins': 100}],
#  'binned_entropy': [{'max_bins': 5},
#   {'max_bins': 10},
#   {'max_bins': 30},
#   {'max_bins': 60}]}

# %%
import antropy as ant
import scipy.stats as ss
from yasa import bandpower

import scipy.stats as ss
from tsflex.features import (
    FeatureCollection,
    FuncWrapper,
    MultipleFeatureDescriptors,
    FuncWrapper,
)
from tsflex.features.integrations import tsfresh_settings_wrapper


def wrapped_higuchi_fd(x):
    x = np.array(x, dtype="float64")
    return ant.higuchi_fd(x)


bands = [
    (0.4, 1, "sdelta"),
    (1, 4, "fdelta"),
    (4, 8, "theta"),
    (8, 12, "alpha"),
    (12, 16, "sigma"),
    (16, 30, "beta"),
]
bandpowers_ouputs = [b[2] for b in bands] + ["TotalAbsPow"]


def wrapped_bandpowers(x, sf, bands):
    return bandpower(x, sf=sf, bands=bands).values[0][:-2]


time_funcs = [
    np.std,
    ss.iqr,
    ss.skew,
    ss.kurtosis,
    ant.num_zerocross,
    FuncWrapper(
        ant.hjorth_params, output_names=["horth_mobility", "hjorth_complexity"]
    ),
    wrapped_higuchi_fd,
    ant.petrosian_fd,
    ant.perm_entropy,
] + tsfresh_settings_wrapper(tsfresh_settings)

freq_funcs = [
    FuncWrapper(wrapped_bandpowers, sf=100, bands=bands, output_names=bandpowers_ouputs)
]

time_feats = MultipleFeatureDescriptors(
    time_funcs,
    ["EEG Fpz-Cz", "EEG Pz-Oz", "EOG horizontal", "EMG submental"],
    windows=["30s", "60s", "90s"],
    strides="30s",
)
freq_feats = MultipleFeatureDescriptors(
    freq_funcs,
    ["EEG Fpz-Cz", "EEG Pz-Oz", "EOG horizontal"],
    windows=["30s", "60s", "90s"],
    strides="30s",
)

feature_collection = FeatureCollection([time_feats, freq_feats])
# fc

# %%
import logging

from tsflex.features.logger import logger

logger.setLevel(level=logging.ERROR)

from tsflex.processing.logger import logger

logger.setLevel(level=logging.ERROR)

# %%
# %%time
feats = feature_collection.calculate(data_processed, return_df=True, show_progress=True)
feats
# Out:
#   0%|          | 0/261 [00:00<?, ?it/s]
#                     EEG Fpz-Cz__TotalAbsPow__w=1m  \
# 1989-04-24 16:13:30                           NaN
# 1989-04-24 16:14:00                    410.013414
# 1989-04-24 16:14:30                    284.113885
# 1989-04-24 16:15:00                    206.055516
# 1989-04-24 16:15:30                    177.742607
# ...                                           ...
# 1989-04-25 14:15:30                    212.469296
# 1989-04-25 14:16:00                     204.06735
# 1989-04-25 14:16:30                    203.696881
# 1989-04-25 14:17:00                    217.303883
# 1989-04-25 14:17:30                    240.720678
#
#                     EEG Fpz-Cz__TotalAbsPow__w=1m30s  \
# 1989-04-24 16:13:30                              NaN
# 1989-04-24 16:14:00                              NaN
# 1989-04-24 16:14:30                       347.419726
# 1989-04-24 16:15:00                       230.349632
# 1989-04-24 16:15:30                       176.336873
# ...                                              ...
# 1989-04-25 14:15:30                       307.817513
# 1989-04-25 14:16:00                       195.455113
# 1989-04-25 14:16:30                       230.956086
# 1989-04-25 14:17:00                       204.767336
# 1989-04-25 14:17:30                       253.853737
#
#                     EEG Fpz-Cz__TotalAbsPow__w=30s EEG Fpz-Cz__alpha__w=1m  \
# 1989-04-24 16:13:30                     552.556158                     NaN
# 1989-04-24 16:14:00                     296.813297                0.018171
# 1989-04-24 16:14:30                     358.240748                0.032559
# 1989-04-24 16:15:00                     187.837507                0.056282
# 1989-04-24 16:15:30                     173.517873                0.068842
# ...                                            ...                     ...
# 1989-04-25 14:15:30                     255.230551                0.036642
# 1989-04-25 14:16:00                     162.540943                0.035044
# 1989-04-25 14:16:30                     287.986357                0.036019
# 1989-04-25 14:17:00                     184.806999                0.037448
# 1989-04-25 14:17:30                     378.740522                0.032094
#
#                     EEG Fpz-Cz__alpha__w=1m30s EEG Fpz-Cz__alpha__w=30s  \
# 1989-04-24 16:13:30                        NaN                 0.011966
# 1989-04-24 16:14:00                        NaN                 0.028862
# 1989-04-24 16:14:30                     0.0239                 0.032287
# 1989-04-24 16:15:00                   0.041142                 0.074854
# 1989-04-24 16:15:30                   0.063116                 0.059463
# ...                                        ...                      ...
# 1989-04-25 14:15:30                   0.025157                 0.030919
# 1989-04-25 14:16:00                   0.036785                 0.035758
# 1989-04-25 14:16:30                   0.031562                 0.026256
# 1989-04-25 14:17:00                   0.038002                 0.047466
# 1989-04-25 14:17:30                   0.030378                 0.018847
#
#                     EEG Fpz-Cz__beta__w=1m EEG Fpz-Cz__beta__w=1m30s  \
# 1989-04-24 16:13:30                    NaN                       NaN
# 1989-04-24 16:14:00               0.024353                       NaN
# 1989-04-24 16:14:30                0.03873                  0.027223
# 1989-04-24 16:15:00                0.03516                  0.036783
# 1989-04-24 16:15:30               0.027978                  0.034582
# ...                                    ...                       ...
# 1989-04-25 14:15:30               0.047035                  0.031875
# 1989-04-25 14:16:00               0.040611                  0.047695
# 1989-04-25 14:16:30               0.047291                  0.039144
# 1989-04-25 14:17:00               0.042533                  0.044301
# 1989-04-25 14:17:30               0.036797                   0.03638
#
#                     EEG Fpz-Cz__beta__w=30s  \
# 1989-04-24 16:13:30                 0.01293
# 1989-04-24 16:14:00                0.046444
# 1989-04-24 16:14:30                0.027552
# 1989-04-24 16:15:00                0.028251
# 1989-04-24 16:15:30                0.027121
# ...                                     ...
# 1989-04-25 14:15:30                0.034681
# 1989-04-25 14:16:00                0.051777
# 1989-04-25 14:16:30                0.034697
# 1989-04-25 14:17:00                0.047973
# 1989-04-25 14:17:30                 0.02403
#
#                      EEG Fpz-Cz__binned_entropy_{'max_bins': 10}__w=1m  ...  \
# 1989-04-24 16:13:30                                                NaN  ...
# 1989-04-24 16:14:00                                           1.667629  ...
# 1989-04-24 16:14:30                                           1.564244  ...
# 1989-04-24 16:15:00                                           1.431736  ...
# 1989-04-24 16:15:30                                           1.376963  ...
# ...                                                                ...  ...
# 1989-04-25 14:15:30                                           1.535747  ...
# 1989-04-25 14:16:00                                           1.621815  ...
# 1989-04-25 14:16:30                                           1.413289  ...
# 1989-04-25 14:17:00                                           1.410208  ...
# 1989-04-25 14:17:30                                           1.507005  ...
#
#                      EOG horizontal__skew__w=30s  EOG horizontal__std__w=1m  \
# 1989-04-24 16:13:30                     0.173134                        NaN
# 1989-04-24 16:14:00                     0.203721                  73.886409
# 1989-04-24 16:14:30                    -0.279640                  70.765891
# 1989-04-24 16:15:00                     0.029593                  47.508646
# 1989-04-24 16:15:30                    -0.439511                  16.211393
# ...                                          ...                        ...
# 1989-04-25 14:15:30                     0.067072                  56.496391
# 1989-04-25 14:16:00                     0.001826                  60.120669
# 1989-04-25 14:16:30                    -0.010830                  66.556921
# 1989-04-25 14:17:00                    -0.041717                  67.617997
# 1989-04-25 14:17:30                     0.082898                  73.320820
#
#                      EOG horizontal__std__w=1m30s  EOG horizontal__std__w=30s  \
# 1989-04-24 16:13:30                           NaN                   71.403606
# 1989-04-24 16:14:00                           NaN                   76.288450
# 1989-04-24 16:14:30                     70.979105                   64.774158
# 1989-04-24 16:15:00                     58.691484                   17.845006
# 1989-04-24 16:15:30                     39.671042                   14.390960
# ...                                           ...                         ...
# 1989-04-25 14:15:30                     64.824067                   62.682500
# 1989-04-25 14:16:00                     56.813446                   57.442227
# 1989-04-25 14:16:30                     65.291381                   74.564612
# 1989-04-25 14:17:00                     64.404993                   59.867784
# 1989-04-25 14:17:30                     73.737804                   84.657491
#
#                      EOG horizontal__theta__w=1m  \
# 1989-04-24 16:13:30                          NaN
# 1989-04-24 16:14:00                     0.042809
# 1989-04-24 16:14:30                     0.032964
# 1989-04-24 16:15:00                     0.064335
# 1989-04-24 16:15:30                      0.10672
# ...                                          ...
# 1989-04-25 14:15:30                     0.058822
# 1989-04-25 14:16:00                     0.045717
# 1989-04-25 14:16:30                     0.059213
# 1989-04-25 14:17:00                     0.056196
# 1989-04-25 14:17:30                      0.05699
#
#                      EOG horizontal__theta__w=1m30s  \
# 1989-04-24 16:13:30                             NaN
# 1989-04-24 16:14:00                             NaN
# 1989-04-24 16:14:30                        0.034947
# 1989-04-24 16:15:00                        0.044394
# 1989-04-24 16:15:30                        0.089847
# ...                                             ...
# 1989-04-25 14:15:30                        0.055937
# 1989-04-25 14:16:00                        0.052746
# 1989-04-25 14:16:30                        0.049297
# 1989-04-25 14:17:00                        0.055605
# 1989-04-25 14:17:30                        0.057639
#
#                      EOG horizontal__theta__w=30s  \
# 1989-04-24 16:13:30                      0.031219
# 1989-04-24 16:14:00                      0.058202
# 1989-04-24 16:14:30                      0.025595
# 1989-04-24 16:15:00                      0.100081
# 1989-04-24 16:15:30                      0.111054
# ...                                           ...
# 1989-04-25 14:15:30                      0.045841
# 1989-04-25 14:16:00                      0.053498
# 1989-04-25 14:16:30                      0.064801
# 1989-04-25 14:17:00                      0.046247
# 1989-04-25 14:17:30                      0.046428
#
#                      EOG horizontal__wrapped_higuchi_fd__w=1m  \
# 1989-04-24 16:13:30                                       NaN
# 1989-04-24 16:14:00                                  1.488313
# 1989-04-24 16:14:30                                  1.607514
# 1989-04-24 16:15:00                                  1.660663
# 1989-04-24 16:15:30                                  1.828444
# ...                                                       ...
# 1989-04-25 14:15:30                                  1.569018
# 1989-04-25 14:16:00                                  1.611479
# 1989-04-25 14:16:30                                  1.699283
# 1989-04-25 14:17:00                                  1.638321
# 1989-04-25 14:17:30                                  1.558671
#
#                      EOG horizontal__wrapped_higuchi_fd__w=1m30s  \
# 1989-04-24 16:13:30                                          NaN
# 1989-04-24 16:14:00                                          NaN
# 1989-04-24 16:14:30                                     1.512376
# 1989-04-24 16:15:00                                     1.652097
# 1989-04-24 16:15:30                                     1.701058
# ...                                                          ...
# 1989-04-25 14:15:30                                     1.608524
# 1989-04-25 14:16:00                                     1.612943
# 1989-04-25 14:16:30                                     1.651181
# 1989-04-25 14:17:00                                     1.653585
# 1989-04-25 14:17:30                                     1.621865
#
#                      EOG horizontal__wrapped_higuchi_fd__w=30s
# 1989-04-24 16:13:30                                   1.257986
# 1989-04-24 16:14:00                                   1.641231
# 1989-04-24 16:14:30                                   1.563791
# 1989-04-24 16:15:00                                   1.830498
# 1989-04-24 16:15:30                                   1.827002
# ...                                                        ...
# 1989-04-25 14:15:30                                   1.519734
# 1989-04-25 14:16:00                                   1.687073
# 1989-04-25 14:16:30                                   1.711871
# 1989-04-25 14:17:00                                   1.516722
# 1989-04-25 14:17:30                                   1.588992
#
# [2649 rows x 363 columns]

# %% [markdown]
# # Pipeline for all patients

# %%
from tqdm.auto import tqdm

df_feats = []
for sub_folder, psg_file, hypnogram_file in tqdm(
    zip(df_files.subfolder, df_files.psg_file, df_files.label_file)
):
    file_folder = data_folder + sub_folder + "/"
    # Load the data, process the data and extract features
    data = load_signals(file_folder + psg_file)
    data_processed = process_pipe.process(data)
    df_feat = feature_collection.calculate(
        data_processed, return_df=True, window_idx="begin"
    ).astype("float32")
    # Add the labels (and reduce features to only data for which we have labels)
    annotations = load_annotations(file_folder + hypnogram_file, file_folder + psg_file)
    annotations = annotation_to_30s_labels(annotations)
    df_feat = df_feat.merge(annotations, left_index=True, right_index=True)
    # Add the file name & folder
    df_feat["psg_file"] = psg_file
    df_feat["patient_id"] = psg_file[:5]
    # Collect the dataframes
    df_feats += [df_feat]

df_feats = pd.concat(df_feats)
df_feats.rename(columns={"description": "label"}, inplace=True)
# Out:
# 0it [00:00, ?it/s]
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1155: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1013: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\antropy\entropy.py:1012: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\tsfresh\feature_extraction\feature_calculators.py:1804: RuntimeWarning:
#
# invalid value encountered in true_divide

# %%
df_feats.to_parquet("sleep-edf__cassette_features_ALL__90s.parquet")

# %% [markdown]
# ## Load data

# %%
df_feats = pd.read_parquet("sleep-edf__cassette_features_ALL__90s.parquet")
df_feats.shape
# Out:
# (416271, 366)

# %%
df_feats["label"].value_counts()
# Out:
# label
# Sleep stage W    285286
# Sleep stage 2     69132
# Sleep stage R     25835
# Sleep stage 1     21521
# Sleep stage 3      8793
# Sleep stage 4      4246
# Sleep stage ?      1330
# Movement time       128
# Name: count, dtype: int64

# %%
df_feats[~df_feats.psg_file.isin(df_files.psg_file.unique())].psg_file.nunique()
# Out:
# 0

# %%
df_feats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 416271 entries, 1989-04-24 16:13:00 to 1991-09-27 14:24:00
# Columns: 366 entries, EEG Fpz-Cz__TotalAbsPow__w=1m to patient_id
# dtypes: float32(363), object(3)
# memory usage: 589.1+ MB

# %%
eeg_signals = [d for d in common_signals if "EEG" in d]
bands = ["alpha", "beta", "sdelta", "fdelta", "sigma", "theta"]
for eeg_sig in eeg_signals:
    eeg_bands = [
        c
        for c in df_feats.columns
        if c.startswith(eeg_sig) and c.split("__")[1] in bands
    ]
    windows = sorted(set(b.split("__")[-1] for b in eeg_bands))
    for window in windows:
        # Select the spectral powers
        delta = (
            df_feats["__".join([eeg_sig, "sdelta", window])]
            + df_feats["__".join([eeg_sig, "fdelta", window])]
        )
        fdelta_theta = (
            df_feats["__".join([eeg_sig, "fdelta", window])]
            + df_feats["__".join([eeg_sig, "theta", window])]
        )
        alpha = df_feats["__".join([eeg_sig, "alpha", window])]
        beta = df_feats["__".join([eeg_sig, "beta", window])]
        theta = df_feats["__".join([eeg_sig, "theta", window])]
        sigma = df_feats["__".join([eeg_sig, "sigma", window])]
        # Calculate the ratios
        df_feats["__".join([eeg_sig, "fdelta+theta", window])] = fdelta_theta.astype(
            "float32"
        )

        df_feats["__".join([eeg_sig, "alpha/theta", window])] = (alpha / theta).astype(
            "float32"
        )
        df_feats["__".join([eeg_sig, "delta/beta", window])] = (delta / beta).astype(
            "float32"
        )
        df_feats["__".join([eeg_sig, "delta/sigma", window])] = (delta / sigma).astype(
            "float32"
        )
        df_feats["__".join([eeg_sig, "delta/theta", window])] = (delta / theta).astype(
            "float32"
        )
df_feats.shape
# Out:
# (416271, 396)

# %%
skip_cols = ["psg_file", "label", "patient_id"]
feat_cols = [c for c in df_feats.columns if c not in skip_cols]

# %%
# Add the 30s features from the minute before and the minute after the epoch (= current sample of 30s) to the epoch
feats_30s = [f for f in df_feats.columns if "w=30s" in f]
feats_60s = [f for f in df_feats.columns if "w=1m_" in f]
feats_90s = [f for f in df_feats.columns if "w=1m30s" in f]
print(len(feats_30s), len(feats_60s), len(feats_90s))
dfs = []
for psg_file in df_feats.psg_file.unique():
    sub_df = df_feats[df_feats.psg_file == psg_file]
    
    sub_df = sub_df.merge(
        sub_df[feats_90s].shift(1).add_suffix("_shift=30s"),
        left_index=True,
        right_index=True,
    )
    sub_df = sub_df.drop(columns=feats_90s)

    sub_df = sub_df.merge(
        sub_df[feats_60s].shift(1).add_suffix("_shift=30s"),
        left_index=True,
        right_index=True,
    )

    sub_df = sub_df.merge(
        sub_df[feats_30s].shift(2).add_suffix("_shift=1m"),
        left_index=True,
        right_index=True,
    )
    sub_df = sub_df.merge(
        sub_df[feats_30s].shift(1).add_suffix("_shift=30s"),
        left_index=True,
        right_index=True,
    )
    sub_df = sub_df.merge(
        sub_df[feats_30s].shift(-1).add_suffix("_shift=-30s"),
        left_index=True,
        right_index=True,
    )
    sub_df = sub_df.merge(
        sub_df[feats_30s].shift(-2).add_suffix("_shift=-1m"),
        left_index=True,
        right_index=True,
    )
    dfs += [sub_df]
df_feats = pd.concat(dfs)
df_feats.shape
# Out:
# 131 0 131
# (416271, 920)

# %%
df_feats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 416271 entries, 1989-04-24 16:13:00 to 1991-09-27 14:24:00
# Columns: 920 entries, EEG Fpz-Cz__TotalAbsPow__w=1m to EEG Pz-Oz__delta/theta__w=30s_shift=-1m
# dtypes: float32(917), object(3)
# memory usage: 1.4+ GB

# %%
# Postprocess labels
df_feats.loc[df_feats["label"] == "Sleep stage 4", "label"] = "Sleep stage 3"
df_feats = df_feats[df_feats["label"] != "Movement time"]
df_feats = df_feats[
    df_feats["label"] != "Sleep stage ?"
]  # Label that is given when recording is done / end of the night

# %%
df_feats_paper = df_feats[df_feats.psg_file.isin(df_files_paper.psg_file)]
df_feats_paper.shape
# Out:
# (106377, 920)

# %%
def get_repeat_length(val, arr):
    assert arr[0] == val
    return np.where(arr != val)[0][0] + 1


dfs = []
for psg_file in df_feats_paper["psg_file"].unique():
    sub_df = df_feats[df_feats.psg_file == psg_file]  # .sort_index()
    labels = sub_df["label"].values
    nb_wake_before_sleep = get_repeat_length("Sleep stage W", labels)
    nb_wake_after_sleep = get_repeat_length("Sleep stage W", labels[::-1])
    start_idx = max(0, nb_wake_before_sleep - 30 * 2)
    end_idx = min(-1, -nb_wake_after_sleep + 30 * 2)
    dfs.append(sub_df[start_idx:end_idx])
df_feats_trimmed_paper = pd.concat(dfs)
del dfs

# %%
def get_repeat_length(val, arr):
    if arr[0] != val:
        return 0
    return np.where(arr != val)[0][0] + 1


dfs = []
for psg_file in df_feats["psg_file"].unique():
    sub_df = df_feats[df_feats.psg_file == psg_file]  # .sort_index()
    labels = sub_df["label"].values
    nb_wake_before_sleep = get_repeat_length("Sleep stage W", labels)
    nb_wake_after_sleep = get_repeat_length("Sleep stage W", labels[::-1])
    start_idx = max(0, nb_wake_before_sleep - 30 * 2)
    end_idx = min(-1, -nb_wake_after_sleep + 30 * 2)
    dfs.append(sub_df[start_idx:end_idx])
df_feats_trimmed_all = pd.concat(dfs)
del dfs

# %% [markdown]
# Prepare training data for SleepEDF-20

# %%
# Subset of data that does not contain the SC-EDF-20 patients
df_feats_trimmed = df_feats_trimmed_all[
    ~df_feats_trimmed_all.psg_file.isin(df_feats_trimmed_paper.psg_file.unique())
]
df_feats_trimmed.shape
# Out:
# (152938, 920)

# %%
any(
    [
        psg_file in df_feats_trimmed_paper.psg_file.unique()
        for psg_file in df_feats_trimmed
    ]
)
# Out:
# False

# %%
# Label stats for the SC-EDF-78 \ SC-EDF20 data
df_feats_trimmed["label"].value_counts()
# Out:
# label
# Sleep stage W    57435
# Sleep stage 2    51333
# Sleep stage 1    18716
# Sleep stage R    18118
# Sleep stage 3     7336
# Name: count, dtype: int64

# %%
# Label stats for the SC-EDF-20 data
print(len(df_feats_trimmed_paper))
df_feats_trimmed_paper["label"].value_counts()
# Out:
# 42230
# label
# Sleep stage 2    17799
# Sleep stage W     8207
# Sleep stage R     7717
# Sleep stage 3     5703
# Sleep stage 1     2804
# Name: count, dtype: int64

# %% [markdown]
# Matches with the samples from other papers

# %%
# Label stats for the SC-EDF-78 data
print(len(df_feats_trimmed_all))
df_feats_trimmed_all["label"].value_counts()
# Out:
# 195168
# label
# Sleep stage 2    69132
# Sleep stage W    65642
# Sleep stage R    25835
# Sleep stage 1    21520
# Sleep stage 3    13039
# Name: count, dtype: int64

# %% [markdown]
# The trimmed wake value count now matches (roughly) the amount of the IITNet & DeepSleepNet paper

# %% [markdown]
# ### Look into nan features

# %%
no_shift_cols = [c for c in df_feats_trimmed_all.columns if not "shift=" in c]# or "w=1m" in c or "w=1m30s" in c]
len(no_shift_cols)
# Out:
# 265

# %%
normal_nan_mask = (df_feats_trimmed_all[no_shift_cols].isna().sum() / df_feats_trimmed_all.psg_file.nunique()).isin([0, 1, 2])
df_feats_trimmed_all[np.array(no_shift_cols)[~normal_nan_mask]].isna().sum().sort_values()[::-1]
# Out:
# EMG submental__wrapped_higuchi_fd__w=30s                        160
# EMG submental__hjorth_complexity__w=30s                         160
# EMG submental__fft_aggregated_{'aggtype': 'skew'}__w=30s        160
# EMG submental__fft_aggregated_{'aggtype': 'kurtosis'}__w=30s    160
# EMG submental__horth_mobility__w=30s                             57
# EMG submental__fourier_entropy_{'bins': 60}__w=30s               57
# EMG submental__fourier_entropy_{'bins': 5}__w=30s                57
# EMG submental__fourier_entropy_{'bins': 3}__w=30s                57
# EMG submental__fourier_entropy_{'bins': 30}__w=30s               57
# EMG submental__fourier_entropy_{'bins': 2}__w=30s                57
# EMG submental__fourier_entropy_{'bins': 10}__w=30s               57
# EMG submental__fourier_entropy_{'bins': 100}__w=30s              57
# EMG submental__fft_aggregated_{'aggtype': 'variance'}__w=30s     32
# EMG submental__fft_aggregated_{'aggtype': 'centroid'}__w=30s     32
# dtype: int64

# %%
df_feats_trimmed_all["psg_file"][df_feats_trimmed_all[np.array(no_shift_cols)[~normal_nan_mask]].isna().any(axis=1)].value_counts()
# Out:
# psg_file
# SC4731E0-PSG.edf    64
# SC4762E0-PSG.edf    48
# SC4332F0-PSG.edf    44
# SC4771G0-PSG.edf     4
# Name: count, dtype: int64

# %%
df_feats_trimmed_all[np.array(no_shift_cols)[~normal_nan_mask]].isna().any(axis=1).sum() / len(df_feats_trimmed_all)
# Out:
# 0.0008198065256599442

# %% [markdown]
# => 0.082% of the feature vectors contain some nan value
#
# *Further findings*: more in depth analysis revealed that the nan values stem from artefacts in the EMG signal (mostly occuring at the beginning and/or end of the sleep period). These signal artefacts induce nan values as some features have the following error *"invalid value encountered in double_scalars"* (possibly due to division by zero).
#
# **What to do with this?**
# For the sake of simplicity we will keep those feature vectors and just (simply) impute the nan values as
# * only 0.082% of the feature vectors (i.e., samples) is affected -> will have minimal / no impact on results
# * other work did not perform artefact removal -> we will include these samples as this allows a "fair" comparison

# %% [markdown]
# ## EDA on labels

# %%
df_feats["label"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='label'>

# %%
df_feats_trimmed_all["label"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='label'>

# %%
df_feats_trimmed_all["label"].value_counts()
# Out:
# label
# Sleep stage 2    69132
# Sleep stage W    65642
# Sleep stage R    25835
# Sleep stage 1    21520
# Sleep stage 3    13039
# Name: count, dtype: int64

# %% [markdown]
# => There is quite some label imbalance

# %% [markdown]
# ## EDA on features

# %%
skip_cols = ["psg_file", "label", "patient_id"]
feat_cols = [c for c in df_feats.columns if c not in skip_cols]

# %%
import math

import matplotlib.pyplot as plt

plot_cols = [c for c in feat_cols if not "_shift=" in c]

# n_cols = 10
# n_rows = math.ceil(len(plot_cols) / n_cols)
# plt.figure(figsize=(n_cols * 4.5, n_rows * 4.5))

# for idx, col in enumerate(plot_cols):
#     plt.subplot(n_rows, n_cols, idx + 1)
#     plt.boxplot(df_feats_trimmed_all[col].dropna(), vert=True)
#     plt.xlabel(col)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # ML

# %%
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    classification_report,
    f1_score,
    cohen_kappa_score,
    log_loss,
)
from sklearn.model_selection import GroupKFold, StratifiedGroupKFold, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import QuantileTransformer

from sklearn.linear_model import SGDClassifier

# %%
from src.visualizations import plot_linear_classification_coefs
from src.visualizations import plot_learning_curve
from src.visualizations import plot_confusion_matrix

# %% [markdown]
# ## The simple, linear pipeline

# %%
### Create pipeline
pipe = Pipeline(
    [
        ("impute", SimpleImputer()),
        ("scale", QuantileTransformer(n_quantiles=100, subsample=200_000, random_state=0)),
        (
            "linear_model",
            SGDClassifier(
                loss="log",
                average=True,
                class_weight="balanced",
                n_jobs=5,
                random_state=0,
            ),
        ),
    ]
)

# %% [markdown]
# ## Linear model for SC-20

# %% [markdown]
# ### Direct transfer from other 58 patients (114 PSGs) to SC-20

# %% [markdown]
# * Train & validatie on all patients except the SC-20 patients (i.e., patient_id > 19)
# * Test the trained model on those 20 patients (i.e., patient_id in [0-19])

# %%
### Fit the pipeline
pipe.fit(df_feats_trimmed[feat_cols], df_feats_trimmed["label"])
# Out:
# C:\Users\erdem\AppData\Roaming\Python\Python38\site-packages\sklearn\linear_model\_stochastic_gradient.py:173: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# Pipeline(steps=[('impute', SimpleImputer()),
#                 ('scale',
#                  QuantileTransformer(n_quantiles=100, random_state=0,
#                                      subsample=200000)),
#                 ('linear_model',
#                  SGDClassifier(average=True, class_weight='balanced',
#                                loss='log', n_jobs=5, random_state=0))])

# %%
print("Training data:")
preds = pipe.predict(df_feats_trimmed[feat_cols])
preds_proba = pipe.predict_proba(df_feats_trimmed[feat_cols])
print("Log loss:", log_loss(y_true=df_feats_trimmed["label"], y_pred=preds_proba))
print(classification_report(y_true=df_feats_trimmed["label"], y_pred=preds))
# Out:
# Training data:
# Log loss: 0.547600827538635
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.54      0.53      0.53     18716
# Sleep stage 2       0.85      0.84      0.84     51333
# Sleep stage 3       0.64      0.87      0.74      7336
# Sleep stage R       0.82      0.85      0.83     18118
# Sleep stage W       0.95      0.92      0.93     57435
#
#      accuracy                           0.83    152938
#     macro avg       0.76      0.80      0.78    152938
#  weighted avg       0.84      0.83      0.83    152938

# %%
print("Testing data:")
preds = pipe.predict(df_feats_trimmed_paper[feat_cols])
preds_proba = pipe.predict_proba(df_feats_trimmed_paper[feat_cols])
print("Log loss:", log_loss(y_true=df_feats_trimmed_paper["label"], y_pred=preds_proba))
print(classification_report(y_true=df_feats_trimmed_paper["label"], y_pred=preds))
# Out:
# Testing data:
# Log loss: 0.4993736441282139
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.50      0.44      0.47      2804
# Sleep stage 2       0.91      0.88      0.89     17799
# Sleep stage 3       0.84      0.93      0.88      5703
# Sleep stage R       0.86      0.88      0.87      7717
# Sleep stage W       0.91      0.92      0.91      8207
#
#      accuracy                           0.86     42230
#     macro avg       0.80      0.81      0.80     42230
#  weighted avg       0.86      0.86      0.86     42230

# %%
print("F1 macro: ", f1_score(preds, df_feats_trimmed_paper["label"], average="macro"))
print("Bal. Acc: ", balanced_accuracy_score(preds, df_feats_trimmed_paper["label"]))
print("Kappa:    ", cohen_kappa_score(preds, df_feats_trimmed_paper["label"]))
print("Log loss :", log_loss(y_true=df_feats_trimmed_paper["label"], y_pred=preds_proba))
# Very bad metric, but appearantly many report it
print("Acc:      ", accuracy_score(preds, df_feats_trimmed_paper["label"]))
# Out:
# F1 macro:  0.8048255829015687
# Bal. Acc:  0.8020726974485829
# Kappa:     0.8134256848181198
# Log loss : 0.4993736441282139
# Acc:       0.8634856736916884

# %%
print("F1 macro: ", f1_score(preds, df_feats_trimmed_paper["label"], average="macro"))
print("Bal. Acc: ", balanced_accuracy_score(preds, df_feats_trimmed_paper["label"]))
print("Kappa:    ", cohen_kappa_score(preds, df_feats_trimmed_paper["label"]))
print("Log loss :", log_loss(y_true=df_feats_trimmed_paper["label"], y_pred=preds_proba))
# Very bad metric, but appearantly many report it
print("Acc:      ", accuracy_score(preds, df_feats_trimmed_paper["label"]))
# Out:
# F1 macro:  0.8048255829015687
# Bal. Acc:  0.8020726974485829
# Kappa:     0.8134256848181198
# Log loss : 0.4993736441282139
# Acc:       0.8634856736916884

# %%
classes = [
    'Sleep stage W',
    'Sleep stage 1',
    'Sleep stage 2',
    'Sleep stage 3',
    'Sleep stage R'
]

plt.figure(figsize=(25,12))
ax = plt.subplot(1,2,1)
plot_confusion_matrix(y_pred=preds, y_true=df_feats_trimmed_paper["label"], classes=classes, normalize=False, ax=ax)
ax = plt.subplot(1,2,2)
plot_confusion_matrix(y_pred=preds, y_true=df_feats_trimmed_paper["label"], classes=classes, normalize=True, ax=ax)
# Out:
# <Axes: title={'center': 'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
import joblib
joblib.dump(pipe, "../models/pipe_DT_SC-20.pkl")
# Out:
# ['../models/pipe_DT_SC-20.pkl']

# %%
cv = StratifiedGroupKFold(n_splits=10).split(
    df_feats_trimmed[feat_cols],
    df_feats_trimmed["label"],
    groups=df_feats_trimmed.patient_id,
)
_ = plot_learning_curve(
    pipe,
    title="Learning curve - F1 Macro",
    X=df_feats_trimmed[feat_cols],
    y=df_feats_trimmed["label"],
    cv=cv,
    scoring="f1_macro",
    n_jobs=25,
    train_sizes=[0.05] + list(np.linspace(0.1,1,10))
)

# %% [markdown]
# #### Basic model analysis

# %%
plot_linear_classification_coefs(pipe, feat_cols=feat_cols)

# %%
df_impact = pd.DataFrame()
df_impact["feature"] = feat_cols
for i, c in enumerate(pipe.classes_):
    df_impact[f"weight_{c}"] = pipe[-1].coef_[i,:]
df_impact["max_abs"] = df_impact.filter(like="weight_").abs().max(axis=1)
df_impact["mean_abs"] = df_impact.filter(like="weight_").abs().mean(axis=1)

def get_shift(feat_name: str):
    if not "shift=" in feat_name or "w=1m" in feat_name:
        return "0"
    return feat_name.split("shift=")[-1]
df_impact["shift"] = df_impact.feature.apply(get_shift)
# print(df_impact["shift"].value_counts())

def get_window_size(feat_name: str):
    return feat_name.split("__w=")[1].split("_")[0]

df_impact["win_size"] = df_impact.feature.apply(get_window_size)
# print(df_impact["win_size"].value_counts())
# print(df_impact[df_impact["shift"] == "0"]["win_size"].value_counts())

df_impact.head(5)
# Out:
#                                 feature  weight_Sleep stage 1  \
# 0   EEG Fpz-Cz__TotalAbsPow__w=1m_s=30s             -0.463573
# 1  EEG Fpz-Cz__TotalAbsPow__w=30s_s=30s             -0.994391
# 2         EEG Fpz-Cz__alpha__w=1m_s=30s              0.657968
# 3        EEG Fpz-Cz__alpha__w=30s_s=30s              1.307413
# 4          EEG Fpz-Cz__beta__w=1m_s=30s              0.504062
#
#    weight_Sleep stage 2  weight_Sleep stage 3  weight_Sleep stage R  \
# 0              0.307579              1.649813             -0.496098
# 1             -0.411936              3.331816             -0.755625
# 2              0.092944              0.035372              0.353163
# 3              0.203579             -0.391866              0.006549
# 4             -0.718899             -0.916129              1.338625
#
#    weight_Sleep stage W   max_abs  mean_abs shift win_size
# 0              0.472800  1.649813  0.677973     0       1m
# 1              1.272647  3.331816  1.353283     0      30s
# 2             -0.682599  0.682599  0.364409     0       1m
# 3             -1.035815  1.307413  0.589044     0      30s
# 4              0.338912  1.338625  0.763325     0       1m

# %%
import seaborn as sns

sub_df = df_impact[df_impact["win_size"] == "30s"]

plt.figure(figsize=(10,6))
plt.title("Mean weight per shifted feature")
# sns.set_context("talk")
sns.boxplot(
    x=sub_df["shift"],
    y=sub_df["mean_abs"],
    order=["-1m", "-30s", "0", "30s", "1m"],
    showfliers=False,
    palette="Set3",
    # height=8,
    # aspect=2,
)
# Out:
# <AxesSubplot:title={'center':'Mean weight per shifted feature'}, xlabel='shift', ylabel='mean_abs'>

# %%
import seaborn as sns

sub_df = df_impact[df_impact["shift"] == "0"]

plt.figure(figsize=(6.5,6))
plt.title("Mean weight per feature window")
# sns.set_context("talk")
sns.boxplot(
    x=sub_df["win_size"].rename("window"),
    y=sub_df["mean_abs"],
    order=["30s", "1m", "1m30s"],
    showfliers=False,
    palette="Set3",
    # height=8,
    # aspect=2,
)
# Out:
# <AxesSubplot:title={'center':'Mean weight per feature window'}, xlabel='window', ylabel='mean_abs'>

# %% [markdown]
# ### Grouped X-fold on SC-20

# %%
# Total of 20 folds
gkfold = GroupKFold(n_splits=20)
cv = gkfold.split(df_feats_trimmed_paper, groups=df_feats_trimmed_paper.patient_id)

res = cross_validate(
    pipe,
    df_feats_trimmed_paper[feat_cols],
    df_feats_trimmed_paper["label"],
    scoring=["f1_macro", "balanced_accuracy", "accuracy", "neg_log_loss"],
    cv=cv,
    n_jobs=30,
    return_train_score=True,
    return_estimator=True,
)

# %%
print("20-FOLD: TRAIN")
print("  MACRO F1:          ", round(np.mean(res["train_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["train_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["train_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["train_neg_log_loss"]), 4))
# Out:
# 20-FOLD: TRAIN
#   MACRO F1:           0.8507
#   Balanced accuracy:  0.8629
#   Accuracy:           0.889
#   Log loss:           0.5912

# %%
print("20-FOLD: TEST")
print("  MACRO F1:          ", round(np.mean(res["test_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["test_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["test_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["test_neg_log_loss"]), 4))
# Out:
# 20-FOLD: TEST
#   MACRO F1:           0.7972
#   Balanced accuracy:  0.8246
#   Accuracy:           0.8563
#   Log loss:           0.9376

# %%
preds = []
preds_proba = []
y_trues = []
cv = gkfold.split(df_feats_trimmed_paper, groups=df_feats_trimmed_paper.patient_id)
for fold_ix, (train_idx, test_idx) in enumerate(cv):
    X_train = df_feats_trimmed_paper[feat_cols].iloc[train_idx]
    y_train = df_feats_trimmed_paper["label"].iloc[train_idx]
    X_test = df_feats_trimmed_paper[feat_cols].iloc[test_idx]
    y_test = df_feats_trimmed_paper["label"].iloc[test_idx]

    estimator = res["estimator"][fold_ix]
    preds += [estimator.predict(X_test)]
    preds_proba += [estimator.predict_proba(X_test)]
    y_trues += [y_test]

preds = np.hstack(preds)
y_trues = np.hstack(y_trues)
preds_proba = np.vstack(preds_proba)

# %%
print("F1:", f1_score(preds, y_trues, average="macro"))
print("ACC:", accuracy_score(preds, y_trues))
print("KAPPA:", cohen_kappa_score(preds, y_trues))
print("LOG LOSS:", log_loss(y_trues, preds_proba))
# Out:
# F1: 0.8090431378353273
# ACC: 0.8572341937011603
# KAPPA: 0.8061718471873169
# LOG LOSS: 0.9436339935460557

# %%
print(classification_report(preds, y_trues))
# Out:
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.56      0.46      0.50      3414
# Sleep stage 2       0.86      0.91      0.88     16803
# Sleep stage 3       0.91      0.83      0.87      6241
# Sleep stage R       0.89      0.87      0.88      7895
# Sleep stage W       0.89      0.93      0.91      7877
#
#      accuracy                           0.86     42230
#     macro avg       0.82      0.80      0.81     42230
#  weighted avg       0.85      0.86      0.85     42230

# %%
classes = [
    'Sleep stage W',
    'Sleep stage 1',
    'Sleep stage 2',
    'Sleep stage 3',
    'Sleep stage R'
]

plt.figure(figsize=(25,12))
ax = plt.subplot(1,2,1)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=False, ax=ax)
ax = plt.subplot(1,2,2)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=True, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
cv = StratifiedGroupKFold(n_splits=10).split(
    df_feats_trimmed_paper[feat_cols],
    df_feats_trimmed_paper["label"],
    groups=df_feats_trimmed_paper.patient_id,
)
_ = plot_learning_curve(
    pipe,
    title="Learning curve - F1 Macro",
    X=df_feats_trimmed_paper[feat_cols],
    y=df_feats_trimmed_paper["label"],
    cv=cv,
    scoring="f1_macro",
    n_jobs=20,
    train_sizes=[0.05] + list(np.linspace(0.1,1,10))
)

# %% [markdown]
# ## Linear model for SC-78

# %% [markdown]
# ### Grouped X-fold on all 78 patients (153 PSGs)

# %%
# Total of 10 folds
gkfold = StratifiedGroupKFold(n_splits=10)
cv = gkfold.split(df_feats_trimmed_all, df_feats_trimmed_all["label"], groups=df_feats_trimmed_all.patient_id)

res = cross_validate(
    pipe,
    df_feats_trimmed_all[feat_cols],
    df_feats_trimmed_all["label"],
    scoring=["f1_macro", "balanced_accuracy", "accuracy", "neg_log_loss"],
    cv=cv,
    n_jobs=30,
    return_train_score=True,
    return_estimator=True,
)

# %%
print("10-FOLD: TRAIN")
print("  MACRO F1:          ", round(np.mean(res["train_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["train_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["train_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["train_neg_log_loss"]), 4))
# Out:
# 10-FOLD: TRAIN
#   MACRO F1:           0.7948
#   Balanced accuracy:  0.8104
#   Accuracy:           0.8406
#   Log loss:           0.5407

# %%
print("10-FOLD: TEST")
print("  MACRO F1:          ", round(np.mean(res["test_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["test_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["test_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["test_neg_log_loss"]), 4))
# Out:
# 10-FOLD: TEST
#   MACRO F1:           0.7697
#   Balanced accuracy:  0.7852
#   Accuracy:           0.8209
#   Log loss:           0.6595

# %%
preds = []
preds_proba = []
y_trues = []
cv = gkfold.split(df_feats_trimmed_all, df_feats_trimmed_all["label"], groups=df_feats_trimmed_all.patient_id)
for fold_ix, (train_idx, test_idx) in enumerate(cv):
    X_train = df_feats_trimmed_all[feat_cols].iloc[train_idx]
    y_train = df_feats_trimmed_all["label"].iloc[train_idx]
    X_test = df_feats_trimmed_all[feat_cols].iloc[test_idx]
    y_test = df_feats_trimmed_all["label"].iloc[test_idx]

    estimator = res["estimator"][fold_ix]
    preds += [estimator.predict(X_test)]
    preds_proba += [estimator.predict_proba(X_test)]
    y_trues += [y_test]

preds = np.hstack(preds)
y_trues = np.hstack(y_trues)
preds_proba = np.vstack(preds_proba)

# %%
print("F1:", f1_score(preds, y_trues, average="macro"))
print("ACC:", accuracy_score(preds, y_trues))
print("KAPPA:", cohen_kappa_score(preds, y_trues))
print("LOG LOSS:", log_loss(y_trues, preds_proba))
# Out:
# F1: 0.7713211218966436
# ACC: 0.821143835054927
# KAPPA: 0.7555750043516509
# LOG LOSS: 0.6583216274717824

# %%
print(classification_report(preds, y_trues))
# Out:
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.49      0.50      0.49     21305
# Sleep stage 2       0.83      0.85      0.84     66993
# Sleep stage 3       0.87      0.71      0.78     16105
# Sleep stage R       0.83      0.82      0.83     26120
# Sleep stage W       0.91      0.92      0.91     64645
#
#      accuracy                           0.82    195168
#     macro avg       0.79      0.76      0.77    195168
#  weighted avg       0.82      0.82      0.82    195168

# %%
classes = [
    'Sleep stage W',
    'Sleep stage 1',
    'Sleep stage 2',
    'Sleep stage 3',
    'Sleep stage R'
]

plt.figure(figsize=(25,12))
ax = plt.subplot(1,2,1)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=False, ax=ax)
ax = plt.subplot(1,2,2)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=True, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
cv = gkfold.split(
    df_feats_trimmed_all[feat_cols],
    df_feats_trimmed_all["label"],
    groups=df_feats_trimmed_all.patient_id,
)
_ = plot_learning_curve(
    pipe,
    title="Learning curve - F1 Macro",
    X=df_feats_trimmed_all[feat_cols],
    y=df_feats_trimmed_all["label"],
    cv=cv,
    scoring="f1_macro",
    n_jobs=20,
    train_sizes=[0.05] + list(np.linspace(0.1,1,10))
)

# %% [markdown]
# ## The simple, catboost pipeline

# %%
### Create pipeline
from catboost import CatBoostClassifier
pipe = CatBoostClassifier(verbose=0, depth=5, n_estimators=2_000, random_state=0)

# %% [markdown]
# ## Catboost model for SC-20

# %% [markdown]
# ### Direct transfer from other 58 patients (114 PSGs) to SC-20

# %% [markdown]
# * Train & validatie on all patients except the SC-20 patients (i.e., patient_id > 19)
# * Test the trained model on those 20 patients (i.e., patient_id in [0-19])

# %%
### Fit the pipeline
pipe.fit(df_feats_trimmed[feat_cols], df_feats_trimmed["label"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 2
#       1 ### Fit the pipeline
# ----> 2 pipe.fit(df_feats_trimmed[feat_cols], df_feats_trimmed["label"])
#
# File ~\AppData\Roaming\Python\Python38\site-packages\catboost\core.py:5220, in CatBoostClassifier.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5217 if 'loss_function' in params:
#    5218     CatBoostClassifier._check_is_compatible_loss(params['loss_function'])
# -> 5220 self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    5221           eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period,
#    5222           silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5223 return self
#
# File ~\AppData\Roaming\Python\Python38\site-packages\catboost\core.py:2400, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2397 allow_clear_pool = train_params["allow_clear_pool"]
#    2399 with plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2400     self._train(
#    2401         train_pool,
#    2402         train_params["eval_sets"],
#    2403         params,
#    2404         allow_clear_pool,
#    2405         train_params["init_model"]
#    2406     )
#    2408 # Have property feature_importance possibly set
#    2409 loss = self._object._get_loss_function_name()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\catboost\core.py:1780, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1779 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1780     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1781     self._set_trained_model_attributes()
#
# File _catboost.pyx:4833, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4882, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
print("Training data:")
preds = pipe.predict(df_feats_trimmed[feat_cols])
preds_proba = pipe.predict_proba(df_feats_trimmed[feat_cols])
print("Log loss:", log_loss(y_true=df_feats_trimmed["label"], y_pred=preds_proba))
print(classification_report(y_true=df_feats_trimmed["label"], y_pred=preds))
# Out:
# Training data:
# Log loss: 0.27783636804781253
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.76      0.61      0.67     18716
# Sleep stage 2       0.87      0.93      0.90     51333
# Sleep stage 3       0.89      0.81      0.85      7336
# Sleep stage R       0.90      0.90      0.90     18118
# Sleep stage W       0.96      0.97      0.96     57435
#
#      accuracy                           0.90    152938
#     macro avg       0.87      0.84      0.86    152938
#  weighted avg       0.89      0.90      0.89    152938

# %%
print("Testing data:")
preds = pipe.predict(df_feats_trimmed_paper[feat_cols])
preds_proba = pipe.predict_proba(df_feats_trimmed_paper[feat_cols])
print("Log loss:", log_loss(y_true=df_feats_trimmed_paper["label"], y_pred=preds_proba))
print(classification_report(y_true=df_feats_trimmed_paper["label"], y_pred=preds))
# Out:
# Testing data:
# Log loss: 0.3610677683293693
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.51      0.46      0.48      2804
# Sleep stage 2       0.89      0.90      0.89     17799
# Sleep stage 3       0.88      0.90      0.89      5703
# Sleep stage R       0.90      0.84      0.87      7717
# Sleep stage W       0.90      0.94      0.92      8207
#
#      accuracy                           0.87     42230
#     macro avg       0.81      0.81      0.81     42230
#  weighted avg       0.86      0.87      0.86     42230

# %%
print("F1 macro: ", f1_score(preds, df_feats_trimmed_paper["label"], average="macro"))
print("Bal. Acc: ", balanced_accuracy_score(preds, df_feats_trimmed_paper["label"]))
print("Kappa:    ", cohen_kappa_score(preds, df_feats_trimmed_paper["label"]))
print("Log loss :", log_loss(y_true=df_feats_trimmed_paper["label"], y_pred=preds_proba))
# Very bad metric, but appearantly many report it
print("Acc:      ", accuracy_score(preds, df_feats_trimmed_paper["label"]))
# Out:
# F1 macro:  0.8101389315276709
# Bal. Acc:  0.813823712917072
# Kappa:     0.8158718355255052
# Log loss : 0.3610677683293693
# Acc:       0.8662325361117689

# %%
classes = [
    'Sleep stage W',
    'Sleep stage 1',
    'Sleep stage 2',
    'Sleep stage 3',
    'Sleep stage R'
]

plt.figure(figsize=(25,12))
ax = plt.subplot(1,2,1)
plot_confusion_matrix(y_pred=preds, y_true=df_feats_trimmed_paper["label"], classes=classes, normalize=False, ax=ax)
ax = plt.subplot(1,2,2)
plot_confusion_matrix(y_pred=preds, y_true=df_feats_trimmed_paper["label"], classes=classes, normalize=True, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
import joblib
joblib.dump(pipe, "../models/catboost_DT_SC-20.pkl")
# Out:
# ['../models/catboost_DT_SC-20.pkl']

# %%
# cv = StratifiedGroupKFold(n_splits=10).split(
#     df_feats_trimmed[feat_cols],
#     df_feats_trimmed["label"],
#     groups=df_feats_trimmed.patient_id,
# )
# _ = plot_learning_curve(
#     pipe,
#     title="Learning curve - F1 Macro",
#     X=df_feats_trimmed[feat_cols],
#     y=df_feats_trimmed["label"],
#     cv=cv,
#     scoring="f1_macro",
#     n_jobs=25,
#     train_sizes=[0.05] + list(np.linspace(0.1,1,10))
# )

# %% [markdown]
# ### Grouped X-fold on SC-20

# %%
# Total of 20 folds
gkfold = GroupKFold(n_splits=20)
cv = gkfold.split(df_feats_trimmed_paper, groups=df_feats_trimmed_paper.patient_id)

res = cross_validate(
    pipe,
    df_feats_trimmed_paper[feat_cols],
    df_feats_trimmed_paper["label"],
    scoring=["f1_macro", "balanced_accuracy", "accuracy", "neg_log_loss"],
    cv=cv,
    # n_jobs=30,
    return_train_score=True,
    return_estimator=True,
)

# %%
print("20-FOLD: TRAIN")
print("  MACRO F1:          ", round(np.mean(res["train_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["train_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["train_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["train_neg_log_loss"]), 4))
# Out:
# 20-FOLD: TRAIN
#   MACRO F1:           0.928
#   Balanced accuracy:  0.9174
#   Accuracy:           0.9469
#   Log loss:           0.1635

# %%
print("20-FOLD: TEST")
print("  MACRO F1:          ", round(np.mean(res["test_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["test_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["test_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["test_neg_log_loss"]), 4))
# Out:
# 20-FOLD: TEST
#   MACRO F1:           0.7956
#   Balanced accuracy:  0.8013
#   Accuracy:           0.8648
#   Log loss:           0.3623

# %%
preds = []
preds_proba = []
y_trues = []
cv = gkfold.split(df_feats_trimmed_paper, groups=df_feats_trimmed_paper.patient_id)
for fold_ix, (train_idx, test_idx) in enumerate(cv):
    X_train = df_feats_trimmed_paper[feat_cols].iloc[train_idx]
    y_train = df_feats_trimmed_paper["label"].iloc[train_idx]
    X_test = df_feats_trimmed_paper[feat_cols].iloc[test_idx]
    y_test = df_feats_trimmed_paper["label"].iloc[test_idx]

    estimator = res["estimator"][fold_ix]
    preds += [estimator.predict(X_test).ravel()]
    preds_proba += [estimator.predict_proba(X_test)]
    y_trues += [y_test]

preds = np.hstack(preds)
y_trues = np.hstack(y_trues)
preds_proba = np.vstack(preds_proba)

# %%
print("F1:", f1_score(preds, y_trues, average="macro"))
print("ACC:", accuracy_score(preds, y_trues))
print("KAPPA:", cohen_kappa_score(preds, y_trues))
print("LOG LOSS:", log_loss(y_trues, preds_proba))
# Out:
# F1: 0.8023727343378386
# ACC: 0.8638171915699739
# KAPPA: 0.8118516489045744
# LOG LOSS: 0.3655665302066996

# %%
print(classification_report(preds, y_trues))
# Out:
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.41      0.53      0.46      2154
# Sleep stage 2       0.91      0.88      0.89     18320
# Sleep stage 3       0.89      0.89      0.89      5731
# Sleep stage R       0.86      0.87      0.87      7675
# Sleep stage W       0.91      0.89      0.90      8350
#
#      accuracy                           0.86     42230
#     macro avg       0.80      0.81      0.80     42230
#  weighted avg       0.87      0.86      0.87     42230

# %%
classes = [
    'Sleep stage W',
    'Sleep stage 1',
    'Sleep stage 2',
    'Sleep stage 3',
    'Sleep stage R'
]

plt.figure(figsize=(25,12))
ax = plt.subplot(1,2,1)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=False, ax=ax)
ax = plt.subplot(1,2,2)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=True, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
# cv = StratifiedGroupKFold(n_splits=10).split(
#     df_feats_trimmed_paper[feat_cols],
#     df_feats_trimmed_paper["label"],
#     groups=df_feats_trimmed_paper.patient_id,
# )
# _ = plot_learning_curve(
#     pipe,
#     title="Learning curve - F1 Macro",
#     X=df_feats_trimmed_paper[feat_cols],
#     y=df_feats_trimmed_paper["label"],
#     cv=cv,
#     scoring="f1_macro",
#     n_jobs=20,
#     train_sizes=[0.05] + list(np.linspace(0.1,1,10))
# )

# %% [markdown]
# ## Catboost model for SC-78

# %% [markdown]
# ### Grouped X-fold on all 78 patients (153 PSGs)

# %%
# Total of 10 folds
gkfold = StratifiedGroupKFold(n_splits=10)
cv = gkfold.split(df_feats_trimmed_all, df_feats_trimmed_all["label"], groups=df_feats_trimmed_all.patient_id)

res = cross_validate(
    pipe,
    df_feats_trimmed_all[feat_cols],
    df_feats_trimmed_all["label"],
    scoring=["f1_macro", "balanced_accuracy", "accuracy", "neg_log_loss"],
    cv=cv,
    # n_jobs=30,
    return_train_score=True,
    return_estimator=True,
)

# %%
print("10-FOLD: TRAIN")
print("  MACRO F1:          ", round(np.mean(res["train_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["train_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["train_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["train_neg_log_loss"]), 4))
# Out:
# 10-FOLD: TRAIN
#   MACRO F1:           0.8611
#   Balanced accuracy:  0.8491
#   Accuracy:           0.8974
#   Log loss:           0.2736

# %%
print("10-FOLD: TEST")
print("  MACRO F1:          ", round(np.mean(res["test_f1_macro"]), 4))
print("  Balanced accuracy: ", round(np.mean(res["test_balanced_accuracy"]), 4))
print("  Accuracy:          ", round(np.mean(res["test_accuracy"]), 4))
print("  Log loss:          ", round(np.mean(-1 * res["test_neg_log_loss"]), 4))
# Out:
# 10-FOLD: TEST
#   MACRO F1:           0.773
#   Balanced accuracy:  0.7641
#   Accuracy:           0.831
#   Log loss:           0.4398

# %%
preds = []
preds_proba = []
y_trues = []
cv = gkfold.split(df_feats_trimmed_all, df_feats_trimmed_all["label"], groups=df_feats_trimmed_all.patient_id)
for fold_ix, (train_idx, test_idx) in enumerate(cv):
    X_train = df_feats_trimmed_all[feat_cols].iloc[train_idx]
    y_train = df_feats_trimmed_all["label"].iloc[train_idx]
    X_test = df_feats_trimmed_all[feat_cols].iloc[test_idx]
    y_test = df_feats_trimmed_all["label"].iloc[test_idx]

    estimator = res["estimator"][fold_ix]
    preds += [estimator.predict(X_test).ravel()]
    preds_proba += [estimator.predict_proba(X_test)]
    y_trues += [y_test]

preds = np.hstack(preds)
y_trues = np.hstack(y_trues)
preds_proba = np.vstack(preds_proba)

# %%
print("F1:", f1_score(preds, y_trues, average="macro"))
print("ACC:", accuracy_score(preds, y_trues))
print("KAPPA:", cohen_kappa_score(preds, y_trues))
print("LOG LOSS:", log_loss(y_trues, preds_proba))
# Out:
# F1: 0.7745358585116534
# ACC: 0.831140350877193
# KAPPA: 0.7653336785403284
# LOG LOSS: 0.4394372921808861

# %%
print(classification_report(preds, y_trues))
# Out:
#                precision    recall  f1-score   support
#
# Sleep stage 1       0.42      0.52      0.46     17297
# Sleep stage 2       0.88      0.82      0.85     73950
# Sleep stage 3       0.78      0.84      0.81     12232
# Sleep stage R       0.80      0.84      0.82     24646
# Sleep stage W       0.93      0.91      0.92     67043
#
#      accuracy                           0.83    195168
#     macro avg       0.76      0.79      0.77    195168
#  weighted avg       0.84      0.83      0.84    195168

# %%
classes = [
    'Sleep stage W',
    'Sleep stage 1',
    'Sleep stage 2',
    'Sleep stage 3',
    'Sleep stage R'
]

plt.figure(figsize=(25,12))
ax = plt.subplot(1,2,1)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=False, ax=ax)
ax = plt.subplot(1,2,2)
plot_confusion_matrix(y_pred=preds, y_true=y_trues, classes=classes, normalize=True, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Normalized confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
# cv = gkfold.split(
#     df_feats_trimmed_all[feat_cols],
#     df_feats_trimmed_all["label"],
#     groups=df_feats_trimmed_all.patient_id,
# )
# _ = plot_learning_curve(
#     pipe,
#     title="Learning curve - F1 Macro",
#     X=df_feats_trimmed_all[feat_cols],
#     y=df_feats_trimmed_all["label"],
#     cv=cv,
#     scoring="f1_macro",
#     n_jobs=20,
# )
